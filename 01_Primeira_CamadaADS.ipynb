# %%
Armazenamento e Gestão de Dados com Data Lake e Data Lakehouse Projeto Final Consolidação, Limpeza e Enriquecimento de Dados de Diferentes Formatos no Data Lakehouse

# %% [markdown]
# Primeira Camada de Armazenamento

# %%
# Cria um banco de dados (schema)
spark.sql("CREATE DATABASE IF NOT EXISTS ads_db_01_inicial")

# %%
# Define o banco a ser usado
spark.sql("USE DATABASE ads_db_01_inicial")

# %%
# Visualiza os bancos de dados criados
#spark.sql('SHOW DATABASES').show()

# %% [markdown]
# ## FIM
